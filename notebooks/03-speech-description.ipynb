# %%
import os

import json
import pandas as pd

from config import DATA_PATH

# %%
out_file = os.path.join(DATA_PATH, "tokens2tag_as_stopw.csv")
tokens2tag = pd.read_csv(
    out_file,
    converters={"pos": eval, "lemmas": eval},
    usecols=["raw", "F", "f", "lemmas", "pos", "use", "pos_correction"]
)
tokens2tag.head()
# Out:
#          raw  F         f        lemmas     pos      use pos_correction
# 0  abandonar  1  0.000011   [abandonar]  [VERB]    lemma            NaN
# 1     abarca  2  0.000022     [abarcar]  [VERB]    lemma            NaN
# 2      abría  1  0.000011        [aber]  [VERB]    lemma            NaN
# 3  abordarlo  1  0.000011  [abordar él]  [VERB]  abordar            NaN
# 4    abordar  4  0.000044     [abordar]  [VERB]    lemma            NaN

# %%
# cantidad de tokens únicos
tokens2tag.shape[0]
# Out:
# 8324

# %%
# cantidad de tokens totales
tokens2tag.F.sum()
# Out:
# 90191

# %%
def is_corrected_lemma(row: pd.Series)  -> str:
    if row.use == "lemma":
        return False
    else:
        return True
    
def is_corrected_pos(row: pd.Series)  -> str:
    if isinstance(row.pos_correction, str):
        return True
    else:
        return False

def select_lemma(row: pd.Series) -> str:
    if row.use == "lemma":
        return row.lemmas[0]
    elif row.use == "FALSE":
        return None
    else:
        return row.use
    
def select_pos(row: pd.Series) -> str:
    if isinstance(row.pos_correction, str):
        return row.pos_correction
    else:
        return row.pos[0]

def lemma_is_in_prediction(row: pd.Series) -> bool:
    if row.use == "lemma":
        return True
    else:
        if row.use in row.lemmas:
            return True
        else:
            return False
    
def pos_is_in_prediction(row: pd.Series) -> bool:
    if isinstance(row.pos_correction, str):
        if row.pos_correction in row.pos:
            return True
        else:
            return False
    else:
        return True

# %%
tokens2tag = (
    tokens2tag
    .assign(
        lemma_corrected=tokens2tag.apply(is_corrected_lemma, axis=1),
        pos_corrected=tokens2tag.apply(is_corrected_pos, axis=1),
        selected_lemma=tokens2tag.apply(select_lemma, axis=1),
        selected_pos=tokens2tag.apply(select_pos, axis=1),
        selected_lemma_in_prediction=tokens2tag.apply(lemma_is_in_prediction, axis=1),
        selected_pos_in_prediction=tokens2tag.apply(pos_is_in_prediction, axis=1)
    )
)
tokens2tag.head()
# Out:
#          raw  F         f        lemmas     pos      use pos_correction  \
# 0  abandonar  1  0.000011   [abandonar]  [VERB]    lemma            NaN
# 1     abarca  2  0.000022     [abarcar]  [VERB]    lemma            NaN
# 2      abría  1  0.000011        [aber]  [VERB]    lemma            NaN
# 3  abordarlo  1  0.000011  [abordar él]  [VERB]  abordar            NaN
# 4    abordar  4  0.000044     [abordar]  [VERB]    lemma            NaN
#
#    lemma_corrected  pos_corrected selected_lemma selected_pos  \
# 0            False          False      abandonar         VERB
# 1            False          False        abarcar         VERB
# 2            False          False           aber         VERB
# 3             True          False        abordar         VERB
# 4            False          False        abordar         VERB
#
#    selected_lemma_in_prediction  selected_pos_in_prediction
# 0                          True                        True
# 1                          True                        True
# 2                          True                        True
# 3                         False                        True
# 4                          True                        True

# %%
# tokens que se desprecian
tokens2remove = tokens2tag[tokens2tag.use == "FALSE"]

print(f"Cantidad de tokens únicos: {tokens2remove.raw.count()}")
print(f"Porcentaje sobre el total de tokens: {round(tokens2remove.f.sum()*100, 3)}%")
(
    tokens2remove
    .selected_pos
    .value_counts(normalize=True)
    .to_frame(name="freq")
    .reset_index(names=["POS"])
    .assign(freq=lambda x: x.freq*100)
)
# Out:
# Cantidad de tokens únicos: 211
# Porcentaje sobre el total de tokens: 1.862%
#      POS       freq
# 0    NUM  91.469194
# 1  PROPN   3.791469
# 2  PUNCT   1.895735
# 3    SYM   1.421801
# 4  CCONJ   0.473934
# 5   NOUN   0.473934
# 6    ADP   0.473934

# %%
# cantidad de lemmas corregidos

tokens2tag = tokens2tag[tokens2tag.use != "FALSE"]
(
    tokens2tag
    .groupby(["lemma_corrected", "selected_lemma_in_prediction"])
    .size()
    .to_frame(name="count")
    .reset_index()
    .assign(
        perc=lambda x: (x["count"]/x["count"].sum())*100
    )
)
# Out:
#    lemma_corrected  selected_lemma_in_prediction  count       perc
# 0            False                          True   6457  79.588315
# 1             True                         False   1195  14.729447
# 2             True                          True    461   5.682238

# %%
# cantidad de POS (tomando en cuenta las correcciones)
# en los lemmas corregidos
(    
    tokens2tag[tokens2tag.lemma_corrected]
    .value_counts("selected_pos")
    .to_frame(name="total")
    .reset_index()
    .assign(
        perc=lambda x: (x.total/x.total.sum())*100
    )
    .merge(
        (
            tokens2tag
            [tokens2tag.lemma_corrected]
            .groupby(["selected_pos","selected_lemma_in_prediction"])
            .size()
            .to_frame(name="pos_count")
            .reset_index()
        )
    )
    .assign(
        pos_perc=lambda x: (x.pos_count/x.total)*100
    )
    .sort_values(by=["total", "pos_count"], ascending=False, ignore_index=True)
)
# Out:
#    selected_pos  total       perc  selected_lemma_in_prediction  pos_count  \
# 0          VERB    790  47.705314                         False        619
# 1          VERB    790  47.705314                          True        171
# 2           ADJ    659  39.794686                         False        521
# 3           ADJ    659  39.794686                          True        138
# 4          NOUN    157   9.480676                          True        115
# 5          NOUN    157   9.480676                         False         42
# 6          PRON     20   1.207729                          True         16
# 7          PRON     20   1.207729                         False          4
# 8           DET     19   1.147343                          True         12
# 9           DET     19   1.147343                         False          7
# 10          ADV      5   0.301932                          True          5
# 11        PROPN      5   0.301932                          True          4
# 12        PROPN      5   0.301932                         False          1
# 13         ADJ       1   0.060386                         False          1
#
#       pos_perc
# 0    78.354430
# 1    21.645570
# 2    79.059181
# 3    20.940819
# 4    73.248408
# 5    26.751592
# 6    80.000000
# 7    20.000000
# 8    63.157895
# 9    36.842105
# 10  100.000000
# 11   80.000000
# 12   20.000000
# 13  100.000000

# %%
# cantidad de POS corregidos
(
    tokens2tag
    .groupby(["pos_corrected", "selected_pos_in_prediction"])
    .size()
    .to_frame(name="count")
    .reset_index()
    .assign(
        perc=lambda x: (x["count"]/x["count"].sum())*100
    )
)
# Out:
#    pos_corrected  selected_pos_in_prediction  count       perc
# 0          False                        True   7111  87.649451
# 1           True                       False    291   3.586836
# 2           True                        True    711   8.763713

# %%
# distribución de POS en el dataset
(
    tokens2tag
    .groupby("selected_pos")
    .size()
    .to_frame("count")
    .reset_index()
    .assign(perc=lambda x: (x["count"]/x["count"].sum())*100)
    .sort_values(by="count", ascending=False, ignore_index=True)
)
# Out:
#    selected_pos  count       perc
# 0          VERB   3372  41.562924
# 1          NOUN   2354  29.015161
# 2           ADJ   1633  20.128189
# 3         PROPN    380   4.683841
# 4           ADV    253   3.118452
# 5          PRON     47   0.579317
# 6           DET     31   0.382103
# 7           ADP     20   0.246518
# 8         SCONJ      9   0.110933
# 9         CCONJ      7   0.086281
# 10         INTJ      4   0.049304
# 11           AD      1   0.012326
# 12         ADJ       1   0.012326
# 13        PUNCT      1   0.012326

# %%
# cantidad de pares lemmas-POS únicos
tokens2tag[["selected_lemma", "selected_pos"]].drop_duplicates().shape[0]
# Out:
# 4892

# %%
selected_lemmas2raw = (
    tokens2tag
    .groupby(["selected_lemma", "selected_pos"])
    .agg(
        count=("F", lambda x: x.sum()),
        raw=("raw", lambda x: x.unique().tolist()),
        raw_count=("F", lambda x: x.to_list())
    )
    .reset_index()
    .sort_values(by="count", ascending=False)
)
selected_lemmas2raw.head()
# Out:
#      selected_lemma selected_pos  count        raw     raw_count
# 2731             la          DET   4909  [las, la]  [1265, 3644]
# 1223             de          ADP   4812       [de]        [4812]
# 3860            que        SCONJ   4465      [que]        [4465]
# 1624             el          DET   3180  [el, los]  [2008, 1172]
# 4849              y        CCONJ   2584        [y]        [2584]

# %%
tokens2lemmas = dict()
for i, row in selected_lemmas2raw.iterrows():
    pos = row.selected_pos
    words = zip(row.raw, row.raw_count)
    for w, c in words:
        pos2lemma = tokens2lemmas.get(w, {})
        pos2lemma[pos] = {"lemma": row.selected_lemma, "count": c}
        tokens2lemmas[w] = pos2lemma

tokens2lemmas
# Out:
# {'las': {'DET': {'lemma': 'la', 'count': 1265}},
#  'la': {'DET': {'lemma': 'la', 'count': 3644}},
#  'de': {'ADP': {'lemma': 'de', 'count': 4812}},
#  'que': {'SCONJ': {'lemma': 'que', 'count': 4465}},
#  'el': {'DET': {'lemma': 'el', 'count': 2008}},
#  'los': {'DET': {'lemma': 'el', 'count': 1172}},
#  'y': {'CCONJ': {'lemma': 'y', 'count': 2584}},
#  'en': {'ADP': {'lemma': 'en', 'count': 2342}},
#  'a': {'ADP': {'lemma': 'a', 'count': 2256}},
#  'fuere': {'VERB': {'lemma': 'ser', 'count': 3}},
#  'sea': {'VERB': {'lemma': 'ser', 'count': 113}},
#  'serlo': {'VERB': {'lemma': 'ser', 'count': 1}},
#  'sean': {'VERB': {'lemma': 'ser', 'count': 19}},
#  'seré': {'VERB': {'lemma': 'ser', 'count': 5}},
#  'era': {'VERB': {'lemma': 'ser', 'count': 72}},
#  'sido': {'VERB': {'lemma': 'ser', 'count': 56}},
#  'será': {'VERB': {'lemma': 'ser', 'count': 35}},
#  'fueron': {'VERB': {'lemma': 'ser', 'count': 28}},
#  'soy': {'VERB': {'lemma': 'ser', 'count': 24}},
#  'siendo': {'VERB': {'lemma': 'ser', 'count': 20}},
#  'sería': {'VERB': {'lemma': 'ser', 'count': 18}},
#  'eran': {'VERB': {'lemma': 'ser', 'count': 11}},
#  'éramos': {'VERB': {'lemma': 'ser', 'count': 4}},
#  'fueran': {'VERB': {'lemma': 'ser', 'count': 4}},
#  'serían': {'VERB': {'lemma': 'ser', 'count': 2}},
#  'serán': {'VERB': {'lemma': 'ser', 'count': 1}},
#  'fuese': {'VERB': {'lemma': 'ser', 'count': 1}},
#  'fue': {'VERB': {'lemma': 'ser', 'count': 90}},
#  'somos': {'VERB': {'lemma': 'ser', 'count': 57}},
#  'seremos': {'VERB': {'lemma': 'ser', 'count': 2}},
#  'seamos': {'VERB': {'lemma': 'ser', 'count': 6}},
#  'ser': {'VERB': {'lemma': 'ser', 'count': 252}},
#  'es': {'VERB': {'lemma': 'ser', 'count': 1247}},
#  'son': {'VERB': {'lemma': 'ser', 'count': 181}},
#  'no': {'ADV': {'lemma': 'no', 'count': 1511}},
#  'se': {'PRON': {'lemma': 'se', 'count': 1042}},
#  'por': {'ADP': {'lemma': 'por', 'count': 943}},
#  'un': {'DET': {'lemma': 'un', 'count': 923}},
#  'tenerlo': {'VERB': {'lemma': 'tener', 'count': 2}},
#  'tenerla': {'VERB': {'lemma': 'tener', 'count': 1}},
#  'tendríamos': {'VERB': {'lemma': 'tener', 'count': 7}},
#  'tenemos': {'VERB': {'lemma': 'tener', 'count': 173}},
#  'tengamos': {'VERB': {'lemma': 'tener', 'count': 8}},
#  'tengan': {'VERB': {'lemma': 'tener', 'count': 20}},
#  'tiene': {'VERB': {'lemma': 'tener', 'count': 270}},
#  'tienen': {'VERB': {'lemma': 'tener', 'count': 101}},
#  'tener': {'VERB': {'lemma': 'tener', 'count': 91}},
#  'tengo': {'VERB': {'lemma': 'tener', 'count': 40}},
#  'tenía': {'VERB': {'lemma': 'tener', 'count': 22}},
#  'tenga': {'VERB': {'lemma': 'tener', 'count': 17}},
#  'tuvo': {'VERB': {'lemma': 'tener', 'count': 16}},
#  'tenido': {'VERB': {'lemma': 'tener', 'count': 16}},
#  'tuvieron': {'VERB': {'lemma': 'tener', 'count': 14}},
#  'tenían': {'VERB': {'lemma': 'tener', 'count': 12}},
#  'teníamos': {'VERB': {'lemma': 'tener', 'count': 11}},
#  'tuvimos': {'VERB': {'lemma': 'tener', 'count': 10}},
#  'tuve': {'VERB': {'lemma': 'tener', 'count': 7}},
#  'tendrá': {'VERB': {'lemma': 'tener', 'count': 5}},
#  'tendremos': {'VERB': {'lemma': 'tener', 'count': 5}},
#  'tuviera': {'VERB': {'lemma': 'tener', 'count': 2}},
#  'tendrán': {'VERB': {'lemma': 'tener', 'count': 2}},
#  'tendría': {'VERB': {'lemma': 'tener', 'count': 1}},
#  'tuviesen': {'VERB': {'lemma': 'tener', 'count': 1}},
#  'tuvieran': {'VERB': {'lemma': 'tener', 'count': 1}},
#  'tenés': {'VERB': {'lemma': 'tener', 'count': 1}},
#  'tuviéramos': {'VERB': {'lemma': 'tener', 'count': 1}},
#  'tuviésemos': {'VERB': {'lemma': 'tener', 'count': 1}},
#  'teniendo': {'VERB': {'lemma': 'tener', 'count': 11}},
#  'tenida': {'VERB': {'lemma': 'tener', 'count': 1}},
#  'haberles': {'VERB': {'lemma': 'haber', 'count': 1}},
#  'haberla': {'VERB': {'lemma': 'haber', 'count': 3}},
#  'hubiere': {'VERB': {'lemma': 'haber', 'count': 1}},
#  'haberse': {'VERB': {'lemma': 'haber', 'count': 5}},
#  'haberlo': {'VERB': {'lemma': 'haber', 'count': 1}},
#  'ha': {'VERB': {'lemma': 'haber', 'count': 174}},
#  'han': {'VERB': {'lemma': 'haber', 'count': 116}},
#  'hemos': {'VERB': {'lemma': 'haber', 'count': 87}},
#  'había': {'VERB': {'lemma': 'haber', 'count': 44}},
#  'haber': {'VERB': {'lemma': 'haber', 'count': 38}},
#  'he': {'VERB': {'lemma': 'haber', 'count': 29}},
#  'haya': {'VERB': {'lemma': 'haber', 'count': 23}},
#  'hubo': {'VERB': {'lemma': 'haber', 'count': 23}},
#  'hubiera': {'VERB': {'lemma': 'haber', 'count': 15}},
#  'habrá': {'VERB': {'lemma': 'haber', 'count': 7}},
#  'habían': {'VERB': {'lemma': 'haber', 'count': 6}},
#  'habido': {'VERB': {'lemma': 'haber', 'count': 5}},
#  'habiendo': {'VERB': {'lemma': 'haber', 'count': 4}},
#  'hayan': {'VERB': {'lemma': 'haber', 'count': 4}},
#  'habría': {'VERB': {'lemma': 'haber', 'count': 3}},
#  'hubiese': {'VERB': {'lemma': 'haber', 'count': 2}},
#  'habremos': {'VERB': {'lemma': 'haber', 'count': 1}},
#  'habíamos': {'VERB': {'lemma': 'haber', 'count': 1}},
#  'hubiéramos': {'VERB': {'lemma': 'haber', 'count': 1}},
#  'hubiésemos': {'VERB': {'lemma': 'haber', 'count': 3}},
#  'hay': {'VERB': {'lemma': 'haber', 'count': 255}},
#  'una': {'DET': {'lemma': 'una', 'count': 828}},
#  'lo': {'PRON': {'lemma': 'lo', 'count': 816}},
#  'estarlo': {'VERB': {'lemma': 'estar', 'count': 2}},
#  'estaré': {'VERB': {'lemma': 'estar', 'count': 1}},
#  'estuviésemos': {'VERB': {'lemma': 'estar', 'count': 1}},
#  'estuviéramos': {'VERB': {'lemma': 'estar', 'count': 2}},
#  'estoy': {'VERB': {'lemma': 'estar', 'count': 57}},
#  'estar': {'VERB': {'lemma': 'estar', 'count': 57}},
#  'estuvo': {'VERB': {'lemma': 'estar', 'count': 9}},
#  'estando': {'VERB': {'lemma': 'estar', 'count': 5}},
#  'estaríamos': {'VERB': {'lemma': 'estar', 'count': 3}},
#  'estaremos': {'VERB': {'lemma': 'estar', 'count': 2}},
#  'estuvieron': {'VERB': {'lemma': 'estar', 'count': 13}},
#  'estemos': {'VERB': {'lemma': 'estar', 'count': 10}},
#  'estén': {'VERB': {'lemma': 'estar', 'count': 9}},
#  'estaría': {'VERB': {'lemma': 'estar', 'count': 5}},
#  'estuviera': {'VERB': {'lemma': 'estar', 'count': 2}},
#  'estarían': {'VERB': {'lemma': 'estar', 'count': 2}},
#  'estarán': {'VERB': {'lemma': 'estar', 'count': 1}},
#  'estuvimos': {'VERB': {'lemma': 'estar', 'count': 1}},
#  'estamos': {'VERB': {'lemma': 'estar', 'count': 265}},
#  'están': {'VERB': {'lemma': 'estar', 'count': 116}},
#  'estaba': {'VERB': {'lemma': 'estar', 'count': 16}},
#  'esté': {'VERB': {'lemma': 'estar', 'count': 10}},
#  'estaban': {'VERB': {'lemma': 'estar', 'count': 6}},
#  'estará': {'VERB': {'lemma': 'estar', 'count': 4}},
#  'estuve': {'VERB': {'lemma': 'estar', 'count': 4}},
#  'está': {'VERB': {'lemma': 'estar', 'count': 198}},
#  'con': {'ADP': {'lemma': 'con', 'count': 785}},
#  'del': {'ADP': {'lemma': 'del', 'count': 778}},
#  'mí': {'PRON': {'lemma': 'yo', 'count': 37}},
#  'conmigo': {'PRON': {'lemma': 'yo', 'count': 1}},
#  'nos': {'PRON': {'lemma': 'yo', 'count': 304}},
#  'me': {'PRON': {'lemma': 'yo', 'count': 223}},
#  'yo': {'PRON': {'lemma': 'yo', 'count': 166}},
#  'mujer': {'NOUN': {'lemma': 'mujer', 'count': 207}},
#  'mujeres': {'NOUN': {'lemma': 'mujer', 'count': 475}},
#  'mundo': {'NOUN': {'lemma': 'mujer', 'count': 47}},
#  'para': {'ADP': {'lemma': 'para', 'count': 676}},
#  'decile': {'VERB': {'lemma': 'decir', 'count': 1}},
#  'decirlo': {'VERB': {'lemma': 'decir', 'count': 7}},
#  'decirles': {'VERB': {'lemma': 'decir', 'count': 13}},
#  'decirle': {'VERB': {'lemma': 'decir', 'count': 6}},
#  'decirse': {'VERB': {'lemma': 'decir', 'count': 1}},
#  'decirnos': {'VERB': {'lemma': 'decir', 'count': 2}},
#  'diciéndonos': {'VERB': {'lemma': 'decir', 'count': 1}},
#  'decía': {'VERB': {'lemma': 'decir', 'count': 32}},
#  'dije': {'VERB': {'lemma': 'decir', 'count': 29}},
#  'dijeron': {'VERB': {'lemma': 'decir', 'count': 17}},
#  'dijo': {'VERB': {'lemma': 'decir', 'count': 70}},
#  'dice': {'VERB': {'lemma': 'decir', 'count': 92}},
#  'dicen': {'VERB': {'lemma': 'decir', 'count': 19}},
#  'decían': {'VERB': {'lemma': 'decir', 'count': 17}},
#  'diciendo': {'VERB': {'lemma': 'decir', 'count': 12}},
#  'decimos': {'VERB': {'lemma': 'decir', 'count': 7}},
#  'diga': {'VERB': {'lemma': 'decir', 'count': 4}},
#  'digan': {'VERB': {'lemma': 'decir', 'count': 4}},
#  'decíamos': {'VERB': {'lemma': 'decir', 'count': 2}},
#  'dijera': {'VERB': {'lemma': 'decir', 'count': 2}},
#  'dirán': {'VERB': {'lemma': 'decir', 'count': 2}},
#  'dijimos': {'VERB': {'lemma': 'decir', 'count': 1}},
#  'dirá': {'VERB': {'lemma': 'decir', 'count': 1}},
#  'dígame': {'VERB': {'lemma': 'decir', 'count': 1}},
#  'dijésemos': {'VERB': {'lemma': 'decir', 'count': 1}},
#  'diría': {'VERB': {'lemma': 'decir', 'count': 9}},
#  'digo': {'VERB': {'lemma': 'decir', 'count': 50}},
#  'decir': {'VERB': {'lemma': 'decir', 'count': 127}},
#  'digamos': {'VERB': {'lemma': 'decir', 'count': 7}},
#  'dicho': {'VERB': {'lemma': 'decir', 'count': 43}},
#  'ley': {'NOUN': {'lemma': 'ley', 'count': 469}},
#  'leyes': {'NOUN': {'lemma': 'ley', 'count': 50}},
#  'libertad': {'NOUN': {'lemma': 'ley', 'count': 50}},
#  'luz': {'NOUN': {'lemma': 'ley', 'count': 10}},
#  'pueda': {'VERB': {'lemma': 'poder', 'count': 41}},
#  'podría': {'VERB': {'lemma': 'poder', 'count': 29}},
#  'puedan': {'VERB': {'lemma': 'poder', 'count': 17}},
#  'podamos': {'VERB': {'lemma': 'poder', 'count': 12}},
#  'pudo': {'VERB': {'lemma': 'poder', 'count': 11}},
#  'podíamos': {'VERB': {'lemma': 'poder', 'count': 6}},
#  'podía': {'VERB': {'lemma': 'poder', 'count': 6}},
#  'podrán': {'VERB': {'lemma': 'poder', 'count': 6}},
#  'podríamos': {'VERB': {'lemma': 'poder', 'count': 5}},
#  'podrá': {'VERB': {'lemma': 'poder', 'count': 5}},
#  'pudieron': {'VERB': {'lemma': 'poder', 'count': 4}},
#  'podrían': {'VERB': {'lemma': 'poder', 'count': 4}},
#  'podían': {'VERB': {'lemma': 'poder', 'count': 3}},
#  'pudiera': {'VERB': {'lemma': 'poder', 'count': 2}},
#  'podido': {'VERB': {'lemma': 'poder', 'count': 2}},
#  'podremos': {'VERB': {'lemma': 'poder', 'count': 2}},
#  'pudiendo': {'VERB': {'lemma': 'poder', 'count': 1}},
#  'pudieran': {'VERB': {'lemma': 'poder', 'count': 1}},
#  'pudimos': {'VERB': {'lemma': 'poder', 'count': 17}},
#  'puede': {'VERB': {'lemma': 'poder', 'count': 132}},
#  'podemos': {'VERB': {'lemma': 'poder', 'count': 81}},
#  'pueden': {'VERB': {'lemma': 'poder', 'count': 43}},
#  'puedo': {'VERB': {'lemma': 'poder', 'count': 20}},
#  'pude': {'VERB': {'lemma': 'poder', 'count': 2}},
#  'poder': {'VERB': {'lemma': 'poder', 'count': 116}},
#  'este': {'DET': {'lemma': 'este', 'count': 530}},
#  'derecho': {'NOUN': {'lemma': 'derecho', 'count': 236}},
#  'derechos': {'NOUN': {'lemma': 'derecho', 'count': 274}},
#  'hacerlo': {'VERB': {'lemma': 'hacer', 'count': 29}},
#  'hacerse': {'VERB': {'lemma': 'hacer', 'count': 15}},
#  'hacerle': {'VERB': {'lemma': 'hacer', 'count': 2}},
#  'hacerla': {'VERB': {'lemma': 'hacer', 'count': 2}},
#  'hacerles': {'VERB': {'lemma': 'hacer', 'count': 1}},
#  'haciéndonos': {'VERB': {'lemma': 'hacer', 'count': 2}},
#  'hacernos': {'VERB': {'lemma': 'hacer', 'count': 4}},
#  'hacerme': {'VERB': {'lemma': 'hacer', 'count': 1}},
#  'hace': {'VERB': {'lemma': 'hacer', 'count': 135}},
#  'hacer': {'VERB': {'lemma': 'hacer', 'count': 133}},
#  'haciendo': {'VERB': {'lemma': 'hacer', 'count': 31}},
#  'hacen': {'VERB': {'lemma': 'hacer', 'count': 29}},
#  'hizo': {'VERB': {'lemma': 'hacer', 'count': 18}},
#  'hacemos': {'VERB': {'lemma': 'hacer', 'count': 18}},
#  'hicieron': {'VERB': {'lemma': 'hacer', 'count': 8}},
#  'hicimos': {'VERB': {'lemma': 'hacer', 'count': 8}},
#  'hagan': {'VERB': {'lemma': 'hacer', 'count': 7}},
#  'hacía': {'VERB': {'lemma': 'hacer', 'count': 7}},
#  'hice': {'VERB': {'lemma': 'hacer', 'count': 7}},
#  'hagamos': {'VERB': {'lemma': 'hacer', 'count': 6}},
#  'hago': {'VERB': {'lemma': 'hacer', 'count': 6}},
#  'haga': {'VERB': {'lemma': 'hacer', 'count': 5}},
#  'hicieran': {'VERB': {'lemma': 'hacer', 'count': 2}},
#  'hacían': {'VERB': {'lemma': 'hacer', 'count': 2}},
#  'hechas': {'VERB': {'lemma': 'hacer', 'count': 1}},
#  'haríamos': {'VERB': {'lemma': 'hacer', 'count': 1}},
#  'hacé': {'VERB': {'lemma': 'hacer', 'count': 1}},
#  'hacérselo': {'VERB': {'lemma': 'hacer', 'count': 1}},
#  'hacíamos': {'VERB': {'lemma': 'hacer', 'count': 1}},
#  'hagámonos': {'VERB': {'lemma': 'hacer', 'count': 2}},
#  'háganlas': {'VERB': {'lemma': 'hacer', 'count': 1}},
#  'háganlo': {'VERB': {'lemma': 'hacer', 'count': 1}},
#  'hiciere': {'VERB': {'lemma': 'hacer', 'count': 1}},
#  'haciéndome': {'VERB': {'lemma': 'hacer', 'count': 1}},
#  'como': {'SCONJ': {'lemma': 'como', 'count': 482}},
#  'sus': {'DET': {'lemma': 'su', 'count': 148}},
#  'su': {'DET': {'lemma': 'su', 'count': 321}},
#  'esta': {'DET': {'lemma': 'esta', 'count': 391}},
#  'estas': {'DET': {'lemma': 'esta', 'count': 68}},
#  'vayamos': {'VERB': {'lemma': 'ir', 'count': 2}},
#  'ir': {'VERB': {'lemma': 'ir', 'count': 24}},
#  'ido': {'VERB': {'lemma': 'ir', 'count': 3}},
#  'vaya': {'VERB': {'lemma': 'ir', 'count': 13}},
#  'iba': {'VERB': {'lemma': 'ir', 'count': 29}},
#  'iban': {'VERB': {'lemma': 'ir', 'count': 5}},
#  'vayan': {'VERB': {'lemma': 'ir', 'count': 2}},
#  'vas': {'VERB': {'lemma': 'ir', 'count': 1}},
#  'irá': {'VERB': {'lemma': 'ir', 'count': 1}},
#  'va': {'VERB': {'lemma': 'ir', 'count': 134}},
#  'vamos': {'VERB': {'lemma': 'ir', 'count': 88}},
#  'van': {'VERB': {'lemma': 'ir', 'count': 43}},
#  'fuimos': {'VERB': {'lemma': 'ir', 'count': 8}},
#  'fui': {'VERB': {'lemma': 'ir', 'count': 3}},
#  'voy': {'VERB': {'lemma': 'ir', 'count': 88}},
#  'porque': {'SCONJ': {'lemma': 'porque', 'count': 421}},
#  'o': {'CCONJ': {'lemma': 'o', 'count': 418}},
#  'vidas': {'NOUN': {'lemma': 'vida', 'count': 49}},
#  'vida': {'NOUN': {'lemma': 'vida', 'count': 339}},
#  'aborto': {'NOUN': {'lemma': 'aborto', 'count': 288}},
#  'abortos': {'NOUN': {'lemma': 'aborto', 'count': 80}},
#  'más': {'ADV': {'lemma': 'más', 'count': 359}},
#  'también': {'ADV': {'lemma': 'también', 'count': 354}},
#  'pero': {'CCONJ': {'lemma': 'pero', 'count': 348}},
#  'queramos': {'VERB': {'lemma': 'querer', 'count': 6}},
#  'quiero': {'VERB': {'lemma': 'querer', 'count': 150}},
#  'quieren': {'VERB': {'lemma': 'querer', 'count': 37}},
#  'queremos': {'VERB': {'lemma': 'querer', 'count': 36}},
#  'quiere': {'VERB': {'lemma': 'querer', 'count': 31}},
#  'quería': {'VERB': {'lemma': 'querer', 'count': 16}},
#  'quieran': {'VERB': {'lemma': 'querer', 'count': 7}},
#  'querían': {'VERB': {'lemma': 'querer', 'count': 6}},
#  'quiera': {'VERB': {'lemma': 'querer', 'count': 5}},
#  'quisiera': {'VERB': {'lemma': 'querer', 'count': 4}},
#  'querrán': {'VERB': {'lemma': 'querer', 'count': 2}},
#  'queriendo': {'VERB': {'lemma': 'querer', 'count': 2}},
#  'quisieron': {'VERB': {'lemma': 'querer', 'count': 2}},
#  'quieras': {'VERB': {'lemma': 'querer', 'count': 1}},
#  'querés': {'VERB': {'lemma': 'querer', 'count': 3}},
#  'quisiese': {'VERB': {'lemma': 'querer', 'count': 1}},
#  'querer': {'VERB': {'lemma': 'querer', 'count': 13}},
#  'hoy': {'ADV': {'lemma': 'hoy', 'count': 298}},
#  'años': {'NOUN': {'lemma': 'año', 'count': 185}},
#  'año': {'NOUN': {'lemma': 'año', 'count': 101}},
#  'mis': {'DET': {'lemma': 'mi', 'count': 55}},
#  'mi': {'DET': {'lemma': 'mi', 'count': 217}},
#  'al': {'ADP': {'lemma': 'al', 'count': 271}},
#  'si': {'SCONJ': {'lemma': 'si', 'count': 270}},
#  'salud': {'NOUN': {'lemma': 'salud', 'count': 263}},
#  'proyecto': {'NOUN': {'lemma': 'proyecto', 'count': 243}},
#  'proyectos': {'NOUN': {'lemma': 'proyecto', 'count': 15}},
#  'esto': {'PRON': {'lemma': 'esto', 'count': 258}},
#  'presidenta': {'NOUN': {'lemma': 'presidenta', 'count': 245}},
#  'esa': {'DET': {'lemma': 'esa', 'count': 166}},
#  'esas': {'DET': {'lemma': 'esa', 'count': 72}},
#  'estado': {'PROPN': {'lemma': 'estado', 'count': 233}},
#  'todos': {'NOUN': {'lemma': 'todo', 'count': 231}},
#  'deberíamos': {'VERB': {'lemma': 'deber', 'count': 8}},
#  'deben': {'VERB': {'lemma': 'deber', 'count': 25}},
#  'debería': {'VERB': {'lemma': 'deber', 'count': 10}},
#  'deberá': {'VERB': {'lemma': 'deber', 'count': 3}},
#  'deberían': {'VERB': {'lemma': 'deber', 'count': 3}},
#  'debía': {'VERB': {'lemma': 'deber', 'count': 3}},
#  'deberán': {'VERB': {'lemma': 'deber', 'count': 2}},
#  'deba': {'VERB': {'lemma': 'deber', 'count': 2}},
#  'debían': {'VERB': {'lemma': 'deber', 'count': 1}},
#  'debíamos': {'VERB': {'lemma': 'deber', 'count': 1}},
#  'debiera': {'VERB': {'lemma': 'deber', 'count': 1}},
#  'debo': {'VERB': {'lemma': 'deber', 'count': 10}},
#  'debe': {'VERB': {'lemma': 'deber', 'count': 92}},
#  'debemos': {'VERB': {'lemma': 'deber', 'count': 59}},
#  'debió': {'VERB': {'lemma': 'deber', 'count': 3}},
#  'embarazos': {'NOUN': {'lemma': 'embarazo', 'count': 36}},
#  'embarazo': {'NOUN': {'lemma': 'embarazo', 'count': 185}},
#  'eso': {'PRON': {'lemma': 'eso', 'count': 217}},
#  'sobre': {'ADP': {'lemma': 'sobre', 'count': 212}},
#  'le': {'PRON': {'lemma': 'él', 'count': 153}},
#  'ellos': {'PRON': {'lemma': 'él', 'count': 32}},
#  'ello': {'PRON': {'lemma': 'él', 'count': 19}},
#  'él': {'PRON': {'lemma': 'él', 'count': 7}},
#  'desde': {'ADP': {'lemma': 'desde', 'count': 201}},
#  'nuestras': {'DET': {'lemma': 'nuestra', 'count': 68}},
#  'nuestra': {'DET': {'lemma': 'nuestra', 'count': 129}},
#  'ese': {'DET': {'lemma': 'ese', 'count': 157}},
#  'esos': {'DET': {'lemma': 'ese', 'count': 36}},
#  'todo': {'ADJ': {'lemma': 'todo', 'count': 185}},
#  'niña': {'NOUN': {'lemma': 'niña', 'count': 21}},
#  'niñas': {'NOUN': {'lemma': 'niña', 'count': 67}},
#  'niño': {'NOUN': {'lemma': 'niña', 'count': 97}},
#  'cuando': {'SCONJ': {'lemma': 'cuando', 'count': 184}},
#  'argentina': {'PROPN': {'lemma': 'argentina', 'count': 178}},
#  'dándonos': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'darle': {'VERB': {'lemma': 'dar', 'count': 13}},
#  'darles': {'VERB': {'lemma': 'dar', 'count': 2}},
#  'darse': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'darla': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'dándose': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'dándole': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'darnos': {'VERB': {'lemma': 'dar', 'count': 4}},
#  'dar': {'VERB': {'lemma': 'dar', 'count': 26}},
#  'da': {'VERB': {'lemma': 'dar', 'count': 24}},
#  'dando': {'VERB': {'lemma': 'dar', 'count': 22}},
#  'dio': {'VERB': {'lemma': 'dar', 'count': 11}},
#  'dan': {'VERB': {'lemma': 'dar', 'count': 8}},
#  'dieron': {'VERB': {'lemma': 'dar', 'count': 6}},
#  'dé': {'VERB': {'lemma': 'dar', 'count': 6}},
#  'damos': {'VERB': {'lemma': 'dar', 'count': 4}},
#  'daban': {'VERB': {'lemma': 'dar', 'count': 2}},
#  'dimos': {'VERB': {'lemma': 'dar', 'count': 2}},
#  'dieran': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'daremos': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'daría': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'dadas': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'daba': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'doy': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'dársela': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'dársele': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'den': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'di': {'VERB': {'lemma': 'dar', 'count': 6}},
#  'dado': {'VERB': {'lemma': 'dar', 'count': 22}},
#  'demos': {'VERB': {'lemma': 'dar', 'count': 3}},
#  'déme': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'denme': {'VERB': {'lemma': 'dar', 'count': 1}},
#  'créame': {'VERB': {'lemma': 'creer', 'count': 1}},
#  'creer': {'VERB': {'lemma': 'creer', 'count': 10}},
#  'creen': {'VERB': {'lemma': 'creer', 'count': 7}},
#  'creemos': {'VERB': {'lemma': 'creer', 'count': 7}},
#  'cree': {'VERB': {'lemma': 'creer', 'count': 3}},
#  'crea': {'VERB': {'lemma': 'creer', 'count': 3}},
#  'creía': {'VERB': {'lemma': 'creer', 'count': 2}},
#  'creyendo': {'VERB': {'lemma': 'creer', 'count': 2}},
#  'creían': {'VERB': {'lemma': 'creer', 'count': 1}},
#  'creyéramos': {'VERB': {'lemma': 'creer', 'count': 1}},
#  'créanme': {'VERB': {'lemma': 'creer', 'count': 2}},
#  'creo': {'VERB': {'lemma': 'creer', 'count': 137}},
#  'temen': {'VERB': {'lemma': 'temer', 'count': 1}},
#  'tema': {'VERB': {'lemma': 'temer', 'count': 173}},
#  'senador': {'NOUN': {'lemma': 'senador', 'count': 109}},
#  'senadores': {'NOUN': {'lemma': 'senador', 'count': 65}},
#  'provincia': {'NOUN': {'lemma': 'provincia', 'count': 114}},
#  'provincias': {'NOUN': {'lemma': 'provincia', 'count': 59}},
#  'sabe': {'VERB': {'lemma': 'saber', 'count': 33}},
#  'sabemos': {'VERB': {'lemma': 'saber', 'count': 45}},
#  'sabíamos': {'VERB': {'lemma': 'saber', 'count': 6}},
#  'sabían': {'VERB': {'lemma': 'saber', 'count': 4}},
#  'sabido': {'VERB': {'lemma': 'saber', 'count': 3}},
#  'supo': {'VERB': {'lemma': 'saber', 'count': 2}},
#  'sabía': {'VERB': {'lemma': 'saber', 'count': 1}},
#  'sabiendo': {'VERB': {'lemma': 'saber', 'count': 1}},
#  'sepan': {'VERB': {'lemma': 'saber', 'count': 1}},
#  'sepa': {'VERB': {'lemma': 'saber', 'count': 1}},
#  'sepamos': {'VERB': {'lemma': 'saber', 'count': 4}},
#  'sé': {'VERB': {'lemma': 'saber', 'count': 27}},
#  'saben': {'VERB': {'lemma': 'saber', 'count': 27}},
#  'saber': {'VERB': {'lemma': 'saber', 'count': 18}},
#  'nuestros': {'DET': {'lemma': 'nuestro', 'count': 50}},
#  'nuestro': {'DET': {'lemma': 'nuestro', 'count': 121}},
#  'hablándole': {'VERB': {'lemma': 'hablar', 'count': 2}},
#  'hablarse': {'VERB': {'lemma': 'hablar', 'count': 1}},
#  'hablarlo': {'VERB': {'lemma': 'hablar', 'count': 1}},
#  'hablarles': {'VERB': {'lemma': 'hablar', 'count': 1}},
#  'hablemos': {'VERB': {'lemma': 'hablar', 'count': 6}},
#  'hablar': {'VERB': {'lemma': 'hablar', 'count': 43}},
#  'habla': {'VERB': {'lemma': 'hablar', 'count': 33}},
#  'hablando': {'VERB': {'lemma': 'hablar', 'count': 30}},
#  'hablamos': {'VERB': {'lemma': 'hablar', 'count': 16}},
#  'habló': {'VERB': {'lemma': 'hablar', 'count': 14}},
#  'hablo': {'VERB': {'lemma': 'hablar', 'count': 3}},
#  'hablaban': {'VERB': {'lemma': 'hablar', 'count': 2}},
#  'hablaron': {'VERB': {'lemma': 'hablar', 'count': 2}},
#  'hablan': {'VERB': {'lemma': 'hablar', 'count': 1}},
#  'hablado': {'VERB': {'lemma': 'hablar', 'count': 1}},
#  'hablen': {'VERB': {'lemma': 'hablar', 'count': 1}},
#  'hable': {'VERB': {'lemma': 'hablar', 'count': 1}},
#  'hablaba': {'VERB': {'lemma': 'hablar', 'count': 10}},
#  'hablándoles': {'VERB': {'lemma': 'hablar', 'count': 1}},
#  'qué': {'PRON': {'lemma': 'qué', 'count': 168}},
#  'gracias': {'NOUN': {'lemma': 'gracia', 'count': 167}},
#  'sra': {'NOUN': {'lemma': 'señora', 'count': 3}},
#  'señora': {'NOUN': {'lemma': 'señora', 'count': 151}},
#  'señoras': {'NOUN': {'lemma': 'señora', 'count': 8}},
#  'otros': {'ADJ': {'lemma': 'otro', 'count': 48}},
#  'otro': {'ADJ': {'lemma': 'otro', 'count': 105}},
#  'país': {'NOUN': {'lemma': 'país', 'count': 124}},
#  'países': {'NOUN': {'lemma': 'país', 'count': 26}},
#  'debates': {'NOUN': {'lemma': 'debate', 'count': 11}},
#  'debate': {'NOUN': {'lemma': 'debate', 'count': 135}},
#  'mucha': {'ADJ': {'lemma': 'mucha', 'count': 12}},
#  'muchas': {'ADJ': {'lemma': 'mucha', 'count': 134}},
#  'veíamos': {'VERB': {'lemma': 'ver', 'count': 1}},
#  'verse': {'VERB': {'lemma': 'ver', 'count': 3}},
#  'visto': {'VERB': {'lemma': 'ver', 'count': 12}},
#  'vemos': {'VERB': {'lemma': 'ver', 'count': 12}},
#  've': {'VERB': {'lemma': 'ver', 'count': 9}},
#  'veo': {'VERB': {'lemma': 'ver', 'count': 5}},
#  'vio': {'VERB': {'lemma': 'ver', 'count': 5}},
#  'ven': {'VERB': {'lemma': 'ver', 'count': 4}},
#  'veamos': {'VERB': {'lemma': 'ver', 'count': 2}},
#  'vieron': {'VERB': {'lemma': 'ver', 'count': 2}},
#  'vimos': {'VERB': {'lemma': 'ver', 'count': 2}},
#  'vi': {'VERB': {'lemma': 'ver', 'count': 1}},
#  'viendo': {'VERB': {'lemma': 'ver', 'count': 1}},
#  'verá': {'VERB': {'lemma': 'ver', 'count': 1}},
#  'vea': {'VERB': {'lemma': 'ver', 'count': 1}},
#  'veremos': {'VERB': {'lemma': 'ver', 'count': 1}},
#  'ver': {'VERB': {'lemma': 'ver', 'count': 80}},
#  'verlas': {'VERB': {'lemma': 'ver', 'count': 1}},
#  'ni': {'CCONJ': {'lemma': 'ni', 'count': 141}},
#  'siga': {'VERB': {'lemma': 'seguir', 'count': 8}},
#  'seguir': {'VERB': {'lemma': 'seguir', 'count': 50}},
#  'siguen': {'VERB': {'lemma': 'seguir', 'count': 21}},
#  'sigue': {'VERB': {'lemma': 'seguir', 'count': 19}},
#  'seguimos': {'VERB': {'lemma': 'seguir', 'count': 11}},
#  'sigan': {'VERB': {'lemma': 'seguir', 'count': 10}},
#  'siguió': {'VERB': {'lemma': 'seguir', 'count': 4}},
#  'siguiendo': {'VERB': {'lemma': 'seguir', 'count': 3}},
#  'sigo': {'VERB': {'lemma': 'seguir', 'count': 3}},
#  'seguiremos': {'VERB': {'lemma': 'seguir', 'count': 2}},
#  'siguieron': {'VERB': {'lemma': 'seguir', 'count': 1}},
#  'seguiré': {'VERB': {'lemma': 'seguir', 'count': 1}},
#  'seguirán': {'VERB': {'lemma': 'seguir', 'count': 1}},
#  'seguido': {'VERB': {'lemma': 'seguir', 'count': 1}},
#  'sigamos': {'VERB': {'lemma': 'seguir', 'count': 5}},
#  'siguiéndolos': {'VERB': {'lemma': 'seguir', 'count': 1}},
#  'sin': {'ADP': {'lemma': 'sin', 'count': 141}},
#  'ya': {'ADV': {'lemma': 'ya', 'count': 139}},
#  'todas': {'NOUN': {'lemma': 'toda', 'count': 136}},
#  'otra': {'ADJ': {'lemma': 'otra', 'count': 72}},
#  'otras': {'ADJ': {'lemma': 'otra', 'count': 60}},
#  'sociedad': {'NOUN': {'lemma': 'sociedad', 'count': 121}},
#  'sociedades': {'NOUN': {'lemma': 'sociedad', 'count': 9}},
#  'decidamos': {'VERB': {'lemma': 'decidir', 'count': 1}},
#  'decida': {'VERB': {'lemma': 'decidir', 'count': 4}},
#  'decidan': {'VERB': {'lemma': 'decidir', 'count': 3}},
#  'decidir': {'VERB': {'lemma': 'decidir', 'count': 75}},
#  'deciden': {'VERB': {'lemma': 'decidir', 'count': 17}},
#  'decidimos': {'VERB': {'lemma': 'decidir', 'count': 8}},
#  'decidido': {'VERB': {'lemma': 'decidir', 'count': 6}},
#  'decide': {'VERB': {'lemma': 'decidir', 'count': 5}},
#  'decidieron': {'VERB': {'lemma': 'decidir', 'count': 3}},
#  'decidió': {'VERB': {'lemma': 'decidir', 'count': 2}},
#  'decidiendo': {'VERB': {'lemma': 'decidir', 'count': 2}},
#  'decidí': {'VERB': {'lemma': 'decidir', 'count': 1}},
#  'decidas': {'VERB': {'lemma': 'decidir', 'count': 2}},
#  'acá': {'ADV': {'lemma': 'acá', 'count': 127}},
#  'caso': {'NOUN': {'lemma': 'caso', 'count': 73}},
#  'casos': {'NOUN': {'lemma': 'caso', 'count': 54}},
#  'días': {'NOUN': {'lemma': 'día', 'count': 73}},
#  'día': {'NOUN': {'lemma': 'día', 'count': 50}},
#  'veces': {'NOUN': {'lemma': 'vez', 'count': 47}},
#  'vez': {'NOUN': {'lemma': 'vez', 'count': 74}},
#  'sociales': {'ADJ': {'lemma': 'social', 'count': 24}},
#  'social': {'ADJ': {'lemma': 'social', 'count': 96}},
#  'nosotros': {'PRON': {'lemma': 'nosotros', 'count': 119}},
#  'cada': {'DET': {'lemma': 'cada', 'count': 118}},
#  'tratarlo': {'VERB': {'lemma': 'tratar', 'count': 2}},
#  'tratándose': {'VERB': {'lemma': 'tratar', 'count': 1}},
#  'tratarse': {'VERB': {'lemma': 'tratar', 'count': 1}},
#  'tratando': {'VERB': {'lemma': 'tratar', 'count': 32}},
#  'tratar': {'VERB': {'lemma': 'tratar', 'count': 25}},
#  'tratamos': {'VERB': {'lemma': 'tratar', 'count': 8}},
#  'trató': {'VERB': {'lemma': 'tratar', 'count': 4}},
#  'trate': {'VERB': {'lemma': 'tratar', 'count': 1}},
#  'tratemos': {'VERB': {'lemma': 'tratar', 'count': 2}},
#  'traten': {'VERB': {'lemma': 'tratar', 'count': 1}},
#  'trata': {'VERB': {'lemma': 'tratar', 'count': 41}},
#  'senadora': {'NOUN': {'lemma': 'senadora', 'count': 77}},
#  'senadoras': {'NOUN': {'lemma': 'senadora', 'count': 37}},
#  'ponerse': {'VERB': {'lemma': 'poner', 'count': 3}},
#  'ponerle': {'VERB': {'lemma': 'poner', 'count': 2}},
#  'ponerlo': {'VERB': {'lemma': 'poner', 'count': 1}},
#  'ponernos': {'VERB': {'lemma': 'poner', 'count': 3}},
#  'poner': {'VERB': {'lemma': 'poner', 'count': 22}},
#  'pone': {'VERB': {'lemma': 'poner', 'count': 16}},
#  'puesto': {'VERB': {'lemma': 'poner', 'count': 13}},
#  'poniendo': {'VERB': {'lemma': 'poner', 'count': 10}},
#  'ponen': {'VERB': {'lemma': 'poner', 'count': 7}},
#  'ponemos': {'VERB': {'lemma': 'poner', 'count': 6}},
#  'puso': {'VERB': {'lemma': 'poner', 'count': 5}},
#  'pongamos': {'VERB': {'lemma': 'poner', 'count': 4}},
#  'ponga': {'VERB': {'lemma': 'poner', 'count': 4}},
#  'pusieron': {'VERB': {'lemma': 'poner', 'count': 3}},
#  'pondrá': {'VERB': {'lemma': 'poner', 'count': 3}},
#  'pongan': {'VERB': {'lemma': 'poner', 'count': 3}},
#  'puse': {'VERB': {'lemma': 'poner', 'count': 2}},
#  'pusimos': {'VERB': {'lemma': 'poner', 'count': 2}},
#  'pongo': {'VERB': {'lemma': 'poner', 'count': 2}},
#  'ponían': {'VERB': {'lemma': 'poner', 'count': 1}},
#  'pongámosle': {'VERB': {'lemma': 'poner', 'count': 1}},
#  'púbica': {'ADJ': {'lemma': 'pública', 'count': 1}},
#  'públicas': {'ADJ': {'lemma': 'pública', 'count': 25}},
#  'pública': {'ADJ': {'lemma': 'pública', 'count': 87}},
#  'tan': {'ADV': {'lemma': 'tanto', 'count': 48}},
#  'tanto': {'ADV': {'lemma': 'tanto', 'count': 60}},
#  'viene': {'VERB': {'lemma': 'venir', 'count': 30}},
#  'venimos': {'VERB': {'lemma': 'venir', 'count': 17}},
#  'vengo': {'VERB': {'lemma': 'venir', 'count': 16}},
#  'vino': {'VERB': {'lemma': 'venir', 'count': 11}},
#  'vienen': {'VERB': {'lemma': 'venir', 'count': 10}},
#  'vinieron': {'VERB': {'lemma': 'venir', 'count': 4}},
#  'venía': {'VERB': {'lemma': 'venir', 'count': 3}},
#  'venir': {'VERB': {'lemma': 'venir', 'count': 3}},
#  'viniera': {'VERB': {'lemma': 'venir', 'count': 1}},
#  'vendrá': {'VERB': {'lemma': 'venir', 'count': 1}},
#  'vinimos': {'VERB': {'lemma': 'venir', 'count': 1}},
#  'vine': {'VERB': {'lemma': 'venir', 'count': 5}},
#  'venido': {'VERB': {'lemma': 'venir', 'count': 5}},
#  'constitución': {'PROPN': {'lemma': 'constitución', 'count': 107}},
#  'algún': {'ADJ': {'lemma': 'alguno', 'count': 30}},
#  'algunos': {'ADJ': {'lemma': 'alguno', 'count': 67}},
#  'alguno': {'ADJ': {'lemma': 'alguno', 'count': 8}},
#  'entonces': {'ADV': {'lemma': 'entonces', 'count': 104}},
#  'interrupciones': {'NOUN': {'lemma': 'interrupción', 'count': 8}},
#  'interrupción': {'NOUN': {'lemma': 'interrupción', 'count': 95}},
#  'palabras': {'NOUN': {'lemma': 'palabra', 'count': 24}},
#  'palabra': {'NOUN': {'lemma': 'palabra', 'count': 78}},
#  'votando': {'VERB': {'lemma': 'votar', 'count': 5}},
#  'votarla': {'VERB': {'lemma': 'votar', 'count': 2}},
#  'votar': {'VERB': {'lemma': 'votar', 'count': 47}},
#  'votaron': {'VERB': {'lemma': 'votar', 'count': 11}},
#  'votan': {'VERB': {'lemma': 'votar', 'count': 6}},
#  'vota': {'VERB': {'lemma': 'votar', 'count': 6}},
#  'votó': {'VERB': {'lemma': 'votar', 'count': 3}},
#  'votaremos': {'VERB': {'lemma': 'votar', 'count': 3}},
#  'votado': {'VERB': {'lemma': 'votar', 'count': 3}},
#  'voten': {'VERB': {'lemma': 'votar', 'count': 3}},
#  'votaba': {'VERB': {'lemma': 'votar', 'count': 2}},
#  'votemos': {'VERB': {'lemma': 'votar', 'count': 2}},
#  'votamos': {'VERB': {'lemma': 'votar', 'count': 2}},
#  'votados': {'VERB': {'lemma': 'votar', 'count': 1}},
#  'votarán': {'VERB': {'lemma': 'votar', 'count': 1}},
#  'vote': {'VERB': {'lemma': 'votar', 'count': 1}},
#  'votarían': {'VERB': {'lemma': 'votar', 'count': 3}},
#  'pasa': {'VERB': {'lemma': 'pasar', 'count': 28}},
#  'pasar': {'VERB': {'lemma': 'pasar', 'count': 20}},
#  'pasó': {'VERB': {'lemma': 'pasar', 'count': 16}},
#  'pasaron': {'VERB': {'lemma': 'pasar', 'count': 9}},
#  'pasando': {'VERB': {'lemma': 'pasar', 'count': 7}},
#  'pasan': {'VERB': {'lemma': 'pasar', 'count': 4}},
#  'pasaba': {'VERB': {'lemma': 'pasar', 'count': 4}},
#  'pasamos': {'VERB': {'lemma': 'pasar', 'count': 3}},
#  'pasará': {'VERB': {'lemma': 'pasar', 'count': 2}},
#  'pase': {'VERB': {'lemma': 'pasar', 'count': 2}},
#  'pasé': {'VERB': {'lemma': 'pasar', 'count': 2}},
#  'pasen': {'VERB': {'lemma': 'pasar', 'count': 1}},
#  'pasara': {'VERB': {'lemma': 'pasar', 'count': 1}},
#  'pasábamos': {'VERB': {'lemma': 'pasar', 'count': 1}},
#  'así': {'ADV': {'lemma': 'así', 'count': 100}},
#  'muy': {'ADV': {'lemma': 'muy', 'count': 99}},
#  'partes': {'NOUN': {'lemma': 'parte', 'count': 10}},
#  'parte': {'NOUN': {'lemma': 'parte', 'count': 73}},
#  'partido': {'NOUN': {'lemma': 'parte', 'count': 12}},
#  'paz': {'NOUN': {'lemma': 'parte', 'count': 3}},
#  'les': {'PRON': {'lemma': 'le', 'count': 97}},
#  'persona': {'NOUN': {'lemma': 'persona', 'count': 97}},
#  'decisión': {'NOUN': {'lemma': 'decisión', 'count': 81}},
#  'decisiones': {'NOUN': {'lemma': 'decisión', 'count': 16}},
#  'uno': {'PRON': {'lemma': 'uno', 'count': 96}},
#  'momento': {'NOUN': {'lemma': 'momento', 'count': 88}},
#  'momentos': {'NOUN': {'lemma': 'momento', 'count': 8}},
#  'dejarse': {'VERB': {'lemma': 'dejar', 'count': 1}},
#  'dejarles': {'VERB': {'lemma': 'dejar', 'count': 1}},
#  'dejarle': {'VERB': {'lemma': 'dejar', 'count': 1}},
#  'dejarlas': {'VERB': {'lemma': 'dejar', 'count': 1}},
#  'dejarnos': {'VERB': {'lemma': 'dejar', 'count': 1}},
#  'dejemos': {'VERB': {'lemma': 'dejar', 'count': 7}},
#  'dejar': {'VERB': {'lemma': 'dejar', 'count': 30}},
#  'deja': {'VERB': {'lemma': 'dejar', 'count': 11}},
#  'dejando': {'VERB': {'lemma': 'dejar', 'count': 6}},
#  'dejan': {'VERB': {'lemma': 'dejar', 'count': 6}},
#  'dejaron': {'VERB': {'lemma': 'dejar', 'count': 4}},
#  'dejó': {'VERB': {'lemma': 'dejar', 'count': 4}},
#  'dejamos': {'VERB': {'lemma': 'dejar', 'count': 3}},
#  'deje': {'VERB': {'lemma': 'dejar', 'count': 3}},
#  'dejado': {'VERB': {'lemma': 'dejar', 'count': 2}},
#  'dejas': {'VERB': {'lemma': 'dejar', 'count': 1}},
#  'dejada': {'VERB': {'lemma': 'dejar', 'count': 1}},
#  'dejaban': {'VERB': {'lemma': 'dejar', 'count': 1}},
#  'dejaba': {'VERB': {'lemma': 'dejar', 'count': 1}},
#  'déjeme': {'VERB': {'lemma': 'dejar', 'count': 2}},
#  'dejen': {'VERB': {'lemma': 'dejar', 'count': 5}},
#  'déjenme': {'VERB': {'lemma': 'dejar', 'count': 1}},
#  'delegarlo': {'VERB': {'lemma': 'dejar', 'count': 1}},
#  'personas': {'NOUN': {'lemma': 'person', 'count': 93}},
#  'artículos': {'NOUN': {'lemma': 'artículo', 'count': 7}},
#  'artículo': {'NOUN': {'lemma': 'artículo', 'count': 85}},
#  'cosas': {'NOUN': {'lemma': 'cosa', 'count': 67}},
#  'cosa': {'NOUN': {'lemma': 'cosa', 'count': 24}},
#  'sí': {'ADV': {'lemma': 'sí', 'count': 90}},
#  'quienes': {'PRON': {'lemma': 'quien', 'count': 62}},
#  'quien': {'PRON': {'lemma': 'quien', 'count': 27}},
#  'presidente': {'NOUN': {'lemma': 'presidente', 'count': 88}},
#  'existe': {'VERB': {'lemma': 'existir', 'count': 44}},
#  'existen': {'VERB': {'lemma': 'existir', 'count': 19}},
#  'existió': {'VERB': {'lemma': 'existir', 'count': 6}},
#  'existiendo': {'VERB': {'lemma': 'existir', 'count': 6}},
#  'existir': {'VERB': {'lemma': 'existir', 'count': 3}},
#  'exista': {'VERB': {'lemma': 'existir', 'count': 3}},
#  'existieron': {'VERB': {'lemma': 'existir', 'count': 2}},
#  'existía': {'VERB': {'lemma': 'existir', 'count': 2}},
#  'existiera': {'VERB': {'lemma': 'existir', 'count': 2}},
#  'existan': {'VERB': {'lemma': 'existir', 'count': 1}},
#  'escuchemos': {'VERB': {'lemma': 'escuchar', 'count': 1}},
#  'escucharlas': {'VERB': {'lemma': 'escuchar', 'count': 2}},
#  'escucharnos': {'VERB': {'lemma': 'escuchar', 'count': 1}},
#  'escuchado': {'VERB': {'lemma': 'escuchar', 'count': 15}},
#  'escuchar': {'VERB': {'lemma': 'escuchar', 'count': 20}},
#  'escucha': {'VERB': {'lemma': 'escuchar', 'count': 13}},
#  'escuchamos': {'VERB': {'lemma': 'escuchar', 'count': 7}},
#  'escuchando': {'VERB': {'lemma': 'escuchar', 'count': 6}},
#  'escuchan': {'VERB': {'lemma': 'escuchar', 'count': 4}},
#  'escuchó': {'VERB': {'lemma': 'escuchar', 'count': 1}},
#  'escucho': {'VERB': {'lemma': 'escuchar', 'count': 1}},
#  'escuchen': {'VERB': {'lemma': 'escuchar', 'count': 1}},
#  'escucharon': {'VERB': {'lemma': 'escuchar', 'count': 1}},
#  'escuchada': {'VERB': {'lemma': 'escuchar', 'count': 1}},
#  'escuchaba': {'VERB': {'lemma': 'escuchar', 'count': 1}},
#  'escuché': {'VERB': {'lemma': 'escuchar', 'count': 11}},
#  'escuche': {'VERB': {'lemma': 'escuchar', 'count': 1}},
#  'donde': {'PRON': {'lemma': 'donde', 'count': 86}},
#  'situación': {'NOUN': {'lemma': 'situación', 'count': 58}},
#  'situaciones': {'NOUN': {'lemma': 'situación', 'count': 27}},
#  'nacional': {'ADJ': {'lemma': 'nacional', 'count': 78}},
#  'nacionales': {'ADJ': {'lemma': 'nacional', 'count': 7}},
#  'muchos': {'ADJ': {'lemma': 'mucho', 'count': 84}},
#  'favor': {'NOUN': {'lemma': 'favor', 'count': 84}},
#  'verdad': {'NOUN': {'lemma': 'verdad', 'count': 82}},
#  'mismos': {'ADJ': {'lemma': 'mismo', 'count': 20}},
#  'mismo': {'ADJ': {'lemma': 'mismo', 'count': 62}},
#  'pensemos': {'VERB': {'lemma': 'pensar', 'count': 2}},
#  'pensar': {'VERB': {'lemma': 'pensar', 'count': 17}},
#  'pienso': {'VERB': {'lemma': 'pensar', 'count': 15}},
#  'piensa': {'VERB': {'lemma': 'pensar', 'count': 12}},
#  'piensan': {'VERB': {'lemma': 'pensar', 'count': 8}},
#  'pensaba': {'VERB': {'lemma': 'pensar', 'count': 6}},
#  'pensamos': {'VERB': {'lemma': 'pensar', 'count': 5}},
#  'pensé': {'VERB': {'lemma': 'pensar', 'count': 3}},
#  'pensando': {'VERB': {'lemma': 'pensar', 'count': 3}},
#  'pensó': {'VERB': {'lemma': 'pensar', 'count': 2}},
#  'pensaban': {'VERB': {'lemma': 'pensar', 'count': 2}},
#  'pensaron': {'VERB': {'lemma': 'pensar', 'count': 1}},
#  'piensen': {'VERB': {'lemma': 'pensar', 'count': 1}},
#  'pensábamos': {'VERB': {'lemma': 'pensar', 'count': 1}},
#  'pensado': {'VERB': {'lemma': 'pensar', 'count': 3}},
#  'cuestión': {'NOUN': {'lemma': 'cuestión', 'count': 51}},
#  'cuestiones': {'NOUN': {'lemma': 'cuestión', 'count': 29}},
#  'realidad': {'NOUN': {'lemma': 'realidad', 'count': 74}},
#  'realidades': {'NOUN': {'lemma': 'realidad', 'count': 6}},
#  'además': {'ADV': {'lemma': 'además', 'count': 78}},
#  'solos': {'ADJ': {'lemma': 'solo', 'count': 2}},
#  'solo': {'ADJ': {'lemma': 'solo', 'count': 76}},
#  'contra': {'ADP': {'lemma': 'contra', 'count': 78}},
#  'ahora': {'ADV': {'lemma': 'ahora', 'count': 77}},
#  'nación': {'PROPN': {'lemma': 'nación', 'count': 76}},
#  'sino': {'CCONJ': {'lemma': 'sino', 'count': 76}},
#  'entendamos': {'VERB': {'lemma': 'entender', 'count': 2}},
#  'entendemos': {'VERB': {'lemma': 'entender', 'count': 2}},
#  'entenderse': {'VERB': {'lemma': 'entender', 'count': 1}},
#  'entenderlo': {'VERB': {'lemma': 'entender', 'count': 1}},
#  'entenderla': {'VERB': {'lemma': 'entender', 'count': 1}},
#  'entendernos': {'VERB': {'lemma': 'entender', 'count': 1}},
#  'entender': {'VERB': {'lemma': 'entender', 'count': 24}},
#  'entendí': {'VERB': {'lemma': 'entender', 'count': 9}},
#  'entiende': {'VERB': {'lemma': 'entender', 'count': 5}},
#  'entendimos': {'VERB': {'lemma': 'entender', 'count': 3}},
#  'entendido': {'VERB': {'lemma': 'entender', 'count': 1}},
#  'entendiendo': {'VERB': {'lemma': 'entender', 'count': 1}},
#  'entendieron': {'VERB': {'lemma': 'entender', 'count': 1}},
#  'entiendan': {'VERB': {'lemma': 'entender', 'count': 1}},
#  'entendiera': {'VERB': {'lemma': 'entender', 'count': 1}},
#  'entienda': {'VERB': {'lemma': 'entender', 'count': 6}},
#  'entiendo': {'VERB': {'lemma': 'entender', 'count': 16}},
#  'entre': {'ADP': {'lemma': 'entre', 'count': 75}},
#  'manera': {'NOUN': {'lemma': 'manera', 'count': 70}},
#  'maneras': {'NOUN': {'lemma': 'manera', 'count': 3}},
#  'sueño': {'NOUN': {'lemma': 'sueño', 'count': 1}},
#  'sueños': {'NOUN': {'lemma': 'sueño', 'count': 2}},
#  'técnica': {'NOUN': {'lemma': 'sueño', 'count': 5}},
#  'tiempo': {'NOUN': {'lemma': 'sueño', 'count': 56}},
#  'tortura': {'NOUN': {'lemma': 'sueño', 'count': 9}},
#  'abortarán': {'VERB': {'lemma': 'abortar', 'count': 2}},
#  'aborta': {'VERB': {'lemma': 'abortar', 'count': 4}},
#  'abortar': {'VERB': {'lemma': 'abortar', 'count': 43}},
#  'abortan': {'VERB': {'lemma': 'abortar', 'count': 11}},
#  'abortaban': {'VERB': {'lemma': 'abortar', 'count': 4}},
#  'abortando': {'VERB': {'lemma': 'abortar', 'count': 3}},
#  'aborte': {'VERB': {'lemma': 'abortar', 'count': 1}},
#  'abortaran': {'VERB': {'lemma': 'abortar', 'count': 1}},
#  'abortara': {'VERB': {'lemma': 'abortar', 'count': 1}},
#  'aborten': {'VERB': {'lemma': 'abortar', 'count': 1}},
#  'abortamos': {'VERB': {'lemma': 'abortar', 'count': 2}},
#  'votos': {'NOUN': {'lemma': 'voto', 'count': 16}},
#  'voto': {'NOUN': {'lemma': 'voto', 'count': 56}},
#  'problema': {'NOUN': {'lemma': 'problema', 'count': 45}},
#  'problemas': {'NOUN': {'lemma': 'problema', 'count': 27}},
#  'sistemas': {'NOUN': {'lemma': 'sistema', 'count': 5}},
#  'sistema': {'NOUN': {'lemma': 'sistema', 'count': 67}},
#  'educación': {'NOUN': {'lemma': 'educación', 'count': 71}},
#  'cómo': {'PRON': {'lemma': 'cómo', 'count': 70}},
#  'mirá': {'VERB': {'lemma': 'mirar', 'count': 2}},
#  'mirándonos': {'VERB': {'lemma': 'mirar', 'count': 1}},
#  'mirarlo': {'VERB': {'lemma': 'mirar', 'count': 1}},
#  'mirarnos': {'VERB': {'lemma': 'mirar', 'count': 1}},
#  'mirar': {'VERB': {'lemma': 'mirar', 'count': 12}},
#  'miramos': {'VERB': {'lemma': 'mirar', 'count': 10}},
#  'mirando': {'VERB': {'lemma': 'mirar', 'count': 7}},
#  'miro': {'VERB': {'lemma': 'mirar', 'count': 2}},
#  'miraba': {'VERB': {'lemma': 'mirar', 'count': 1}},
#  'mira': {'VERB': {'lemma': 'mirar', 'count': 1}},
#  'miró': {'VERB': {'lemma': 'mirar', 'count': 1}},
#  'mire': {'VERB': {'lemma': 'mirar', 'count': 19}},
#  'miren': {'VERB': {'lemma': 'mirar', 'count': 11}},
#  'clandestinidad': {'NOUN': {'lemma': 'clandestinidad', 'count': 69}},
#  'sexuales': {'ADJ': {'lemma': 'sexual', 'count': 2}},
#  'sexual': {'ADJ': {'lemma': 'sexual', 'count': 66}},
#  'acompañamos': {'VERB': {'lemma': 'acompañar', 'count': 1}},
#  'acompañarlas': {'VERB': {'lemma': 'acompañar', 'count': 3}},
#  'acompañarlo': {'VERB': {'lemma': 'acompañar', 'count': 1}},
#  'acompañar': {'VERB': {'lemma': 'acompañar', 'count': 32}},
#  'acompañando': {'VERB': {'lemma': 'acompañar', 'count': 6}},
#  'acompañe': {'VERB': {'lemma': 'acompañar', 'count': 6}},
#  'acompaña': {'VERB': {'lemma': 'acompañar', 'count': 5}},
#  'acompañan': {'VERB': {'lemma': 'acompañar', 'count': 4}},
#  'acompañaron': {'VERB': {'lemma': 'acompañar', 'count': 3}},
#  'acompañado': {'VERB': {'lemma': 'acompañar', 'count': 2}},
#  'acompañó': {'VERB': {'lemma': 'acompañar', 'count': 1}},
#  'acompañarán': {'VERB': {'lemma': 'acompañar', 'count': 1}},
#  'acompañen': {'VERB': {'lemma': 'acompañar', 'count': 1}},
#  'acompañándonos': {'VERB': {'lemma': 'acompañar', 'count': 1}},
#  'acompaño”': {'VERB': {'lemma': 'acompañar', 'count': 1}},
#  'nadie': {'PRON': {'lemma': 'nadie', 'count': 68}},
#  'nada': {'NOUN': {'lemma': 'nada', 'count': 68}},
#  'lugar': {'NOUN': {'lemma': 'lugar', 'count': 57}},
#  'lugares': {'NOUN': {'lemma': 'lugar', 'count': 10}},
#  'siempre': {'ADV': {'lemma': 'siempre', 'count': 67}},
#  'llevarlo': {'VERB': {'lemma': 'llevar', 'count': 3}},
#  'llevándolas': {'VERB': {'lemma': 'llevar', 'count': 1}},
#  'llevarla': {'VERB': {'lemma': 'llevar', 'count': 1}},
#  'llevar': {'VERB': {'lemma': 'llevar', 'count': 24}},
#  'lleva': {'VERB': {'lemma': 'llevar', 'count': 12}},
#  'llevando': {'VERB': {'lemma': 'llevar', 'count': 5}},
#  'llevó': {'VERB': {'lemma': 'llevar', 'count': 4}},
#  'lleve': {'VERB': {'lemma': 'llevar', 'count': 4}},
#  'llevan': {'VERB': {'lemma': 'llevar', 'count': 4}},
#  'llevaron': {'VERB': {'lemma': 'llevar', 'count': 3}},
#  'llevamos': {'VERB': {'lemma': 'llevar', 'count': 3}},
#  'llevaran': {'VERB': {'lemma': 'llevar', 'count': 1}},
#  'llevará': {'VERB': {'lemma': 'llevar', 'count': 1}},
#  'llevemos': {'VERB': {'lemma': 'llevar', 'count': 1}},
#  'madre': {'NOUN': {'lemma': 'madre', 'count': 24}},
#  'madres': {'NOUN': {'lemma': 'madre', 'count': 29}},
#  'medicina': {'NOUN': {'lemma': 'madre', 'count': 6}},
#  'micrófono': {'NOUN': {'lemma': 'madre', 'count': 4}},
#  'milagro': {'NOUN': {'lemma': 'madre', 'count': 3}},
#  'mucho': {'ADV': {'lemma': 'mucho', 'count': 66}},
#  'algo': {'PRON': {'lemma': 'algo', 'count': 66}},
#  'gestantes': {'ADJ': {'lemma': 'gestante', 'count': 36}},
#  'gestante': {'ADJ': {'lemma': 'gestante', 'count': 30}},
#  'nació': {'VERB': {'lemma': 'nacer', 'count': 5}},
#  'nace': {'VERB': {'lemma': 'nacer', 'count': 3}},
#  'nazca': {'VERB': {'lemma': 'nacer', 'count': 2}},
#  'nacieron': {'VERB': {'lemma': 'nacer', 'count': 2}},
#  'nacen': {'VERB': {'lemma': 'nacer', 'count': 1}},
#  'nacemos': {'VERB': {'lemma': 'nacer', 'count': 1}},
#  'nacer': {'VERB': {'lemma': 'nacer', 'count': 39}},
#  'nací': {'VERB': {'lemma': 'nacer', 'count': 4}},
#  'nacido': {'VERB': {'lemma': 'nacer', 'count': 8}},
#  'hasta': {'ADP': {'lemma': 'hasta', 'count': 65}},
#  'tomarle': {'VERB': {'lemma': 'tomar', 'count': 1}},
#  'tomar': {'VERB': {'lemma': 'tomar', 'count': 22}},
#  'tomado': {'VERB': {'lemma': 'tomar', 'count': 7}},
#  'tomaron': {'VERB': {'lemma': 'tomar', 'count': 5}},
#  'tomando': {'VERB': {'lemma': 'tomar', 'count': 4}},
#  'toman': {'VERB': {'lemma': 'tomar', 'count': 4}},
#  'tomo': {'VERB': {'lemma': 'tomar', 'count': 2}},
#  'tomamos': {'VERB': {'lemma': 'tomar', 'count': 2}},
#  'tomarán': {'VERB': {'lemma': 'tomar', 'count': 1}},
#  'tomé': {'VERB': {'lemma': 'tomar', 'count': 1}},
#  'tomó': {'VERB': {'lemma': 'tomar', 'count': 1}},
#  'tomaba': {'VERB': {'lemma': 'tomar', 'count': 1}},
#  'tomará': {'VERB': {'lemma': 'tomar', 'count': 1}},
#  'tome': {'VERB': {'lemma': 'tomar', 'count': 1}},
#  'tomemos': {'VERB': {'lemma': 'tomar', 'count': 4}},
#  'toma': {'VERB': {'lemma': 'tomar', 'count': 8}},
#  'muerte': {'NOUN': {'lemma': 'muerte', 'count': 41}},
#  'muertes': {'NOUN': {'lemma': 'muerte', 'count': 23}},
#  'menos': {'ADV': {'lemma': 'menos', 'count': 64}},
#  'señores': {'NOUN': {'lemma': 'señor', 'count': 12}},
#  'señor': {'NOUN': {'lemma': 'señor', 'count': 52}},
#  'llegar': {'VERB': {'lemma': 'llegar', 'count': 15}},
#  'llega': {'VERB': {'lemma': 'llegar', 'count': 8}},
#  'llegado': {'VERB': {'lemma': 'llegar', 'count': 8}},
#  'llegue': {'VERB': {'lemma': 'llegar', 'count': 7}},
#  'llegó': {'VERB': {'lemma': 'llegar', 'count': 7}},
#  'lleguen': {'VERB': {'lemma': 'llegar', 'count': 4}},
#  'llegan': {'VERB': {'lemma': 'llegar', 'count': 3}},
#  'llegaron': {'VERB': {'lemma': 'llegar', 'count': 2}},
#  'llegara': {'VERB': {'lemma': 'llegar', 'count': 2}},
#  'llegamos': {'VERB': {'lemma': 'llegar', 'count': 2}},
#  'llegues': {'VERB': {'lemma': 'llegar', 'count': 1}},
#  'llegando': {'VERB': {'lemma': 'llegar', 'count': 1}},
#  'llegaban': {'VERB': {'lemma': 'llegar', 'count': 1}},
#  'llegábamos': {'VERB': {'lemma': 'llegar', 'count': 1}},
#  'llegaste': {'VERB': {'lemma': 'llegar', 'count': 1}},
#  'aquí': {'ADV': {'lemma': 'aquí', 'count': 63}},
#  'voluntarias': {'ADJ': {'lemma': 'voluntaria', 'count': 1}},
#  'voluntaria': {'ADJ': {'lemma': 'voluntaria', 'count': 62}},
#  'estos': {'DET': {'lemma': 'esto', 'count': 63}},
#  'argentinos': {'ADJ': {'lemma': 'argentino', 'count': 36}},
#  'argentino': {'ADJ': {'lemma': 'argentino', 'count': 26}},
#  'clandestinos': {'ADJ': {'lemma': 'clandestino', 'count': 28}},
#  'clandestino': {'ADJ': {'lemma': 'clandestino', 'count': 34}},
#  'mismas': {'ADJ': {'lemma': 'misma', 'count': 18}},
#  'misma': {'ADJ': {'lemma': 'misma', 'count': 43}},
#  'respetos': {'NOUN': {'lemma': 'respeto', 'count': 1}},
#  'respeto': {'NOUN': {'lemma': 'respeto', 'count': 60}},
#  'política': {'NOUN': {'lemma': 'política', 'count': 60}},
#  'permitirlos': {'VERB': {'lemma': 'permitir', 'count': 1}},
#  'permite': {'VERB': {'lemma': 'permitir', 'count': 15}},
#  'permitir': {'VERB': {'lemma': 'permitir', 'count': 9}},
#  'permitió': {'VERB': {'lemma': 'permitir', 'count': 5}},
#  'permitía': {'VERB': {'lemma': 'permitir', 'count': 4}},
#  'permita': {'VERB': {'lemma': 'permitir', 'count': 3}},
#  'permitan': {'VERB': {'lemma': 'permitir', 'count': 3}},
#  'permiten': {'VERB': {'lemma': 'permitir', 'count': 3}},
#  'permitiendo': {'VERB': {'lemma': 'permitir', 'count': 2}},
#  'permitiera': {'VERB': {'lemma': 'permitir', 'count': 2}},
#  'permitimos': {'VERB': {'lemma': 'permitir', 'count': 2}},
#  'permitieron': {'VERB': {'lemma': 'permitir', 'count': 1}},
#  'permítame': {'VERB': {'lemma': 'permitir', 'count': 6}},
#  'permitido': {'VERB': {'lemma': 'permitir', 'count': 3},
#   'ADJ ': {'lemma': 'prmitido', 'count': 1}},
#  'después': {'ADV': {'lemma': 'después', 'count': 58}},
#  'ellas': {'PRON': {'lemma': 'ella', 'count': 44}},
#  'ella': {'PRON': {'lemma': 'ella', 'count': 14}},
#  'integrales': {'ADJ': {'lemma': 'integral', 'count': 2}},
#  'integral': {'ADJ': {'lemma': 'integral', 'count': 56}},
#  'bien': {'ADJ': {'lemma': 'bien', 'count': 58}},
#  'aquel': {'ADJ': {'lemma': 'aquel', 'count': 13}},
#  'aquellos': {'ADJ': {'lemma': 'aquel', 'count': 45}},
#  'quedarse': {'VERB': {'lemma': 'quedar', 'count': 1}},
#  'quedarnos': {'VERB': {'lemma': 'quedar', 'count': 1}},
#  'queda': {'VERB': {'lemma': 'quedar', 'count': 13}},
#  'quedar': {'VERB': {'lemma': 'quedar', 'count': 10}},
#  'quedan': {'VERB': {'lemma': 'quedar', 'count': 6}},
#  'quedado': {'VERB': {'lemma': 'quedar', 'count': 5}},
#  'quede': {'VERB': {'lemma': 'quedar', 'count': 5}},
#  'quedó': {'VERB': {'lemma': 'quedar', 'count': 3}},
#  'quedaron': {'VERB': {'lemma': 'quedar', 'count': 3}},
#  'queden': {'VERB': {'lemma': 'quedar', 'count': 2}},
#  'quedo': {'VERB': {'lemma': 'quedar', 'count': 1}},
#  'quedara': {'VERB': {'lemma': 'quedar', 'count': 1}},
#  'quedando': {'VERB': {'lemma': 'quedar', 'count': 1}},
#  'quedamos': {'VERB': {'lemma': 'quedar', 'count': 1}},
#  'quedaban': {'VERB': {'lemma': 'quedar', 'count': 1}},
#  'quedaba': {'VERB': {'lemma': 'quedar', 'count': 1}},
#  'quedate': {'VERB': {'lemma': 'quedar', 'count': 2}},
#  'quédense': {'VERB': {'lemma': 'quedar', 'count': 1}},
#  'código': {'PROPN': {'lemma': 'código', 'count': 57}},
#  'autonomía': {'NOUN': {'lemma': 'autonomía', 'count': 52}},
#  'autonomías': {'NOUN': {'lemma': 'autonomía', 'count': 5}},
#  'propia': {'ADJ': {'lemma': 'propio', 'count': 24}},
#  'propios': {'ADJ': {'lemma': 'propio', 'count': 9}},
#  'propio': {'ADJ': {'lemma': 'propio', 'count': 23}},
#  'lado': {'NOUN': {'lemma': 'lado', 'count': 51}},
#  'lados': {'NOUN': {'lemma': 'lado', 'count': 5}},
#  'humanos': {'NOUN': {'lemma': 'humano', 'count': 55}},
#  'cambiarlo': {'VERB': {'lemma': 'cambiar', 'count': 1}},
#  'cambiar': {'VERB': {'lemma': 'cambiar', 'count': 12}},
#  'cambió': {'VERB': {'lemma': 'cambiar', 'count': 8}},
#  'cambiado': {'VERB': {'lemma': 'cambiar', 'count': 7}},
#  'cambia': {'VERB': {'lemma': 'cambiar', 'count': 4}},
#  'cambiaron': {'VERB': {'lemma': 'cambiar', 'count': 4}},
#  'cambie': {'VERB': {'lemma': 'cambiar', 'count': 4}},
#  'cambian': {'VERB': {'lemma': 'cambiar', 'count': 3}},
#  'cambiando': {'VERB': {'lemma': 'cambiar', 'count': 2}},
#  'cambiará': {'VERB': {'lemma': 'cambiar', 'count': 1}},
#  'cambiaremos': {'VERB': {'lemma': 'cambiar', 'count': 1}},
#  'cambiaran': {'VERB': {'lemma': 'cambiar', 'count': 1}},
#  'cambiara': {'VERB': {'lemma': 'cambiar', 'count': 1}},
#  'cambiamos': {'VERB': {'lemma': 'cambiar', 'count': 1}},
#  'cambié': {'VERB': {'lemma': 'cambiar', 'count': 3}},
#  'cambien': {'VERB': {'lemma': 'cambiar', 'count': 2}},
#  'formas': {'NOUN': {'lemma': 'forma', 'count': 5}},
#  'forma': {'NOUN': {'lemma': 'forma', 'count': 50}},
#  'garantizarlo': {'VERB': {'lemma': 'garantizar', 'count': 1}},
#  'garantizar': {'VERB': {'lemma': 'garantizar', 'count': 28}},
#  'garantiza': {'VERB': {'lemma': 'garantizar', 'count': 8}},
#  'garantice': {'VERB': {'lemma': 'garantizar', 'count': 7}},
#  'garanticen': {'VERB': {'lemma': 'garantizar', 'count': 2}},
#  'garantizarán': {'VERB': {'lemma': 'garantizar', 'count': 1}},
#  'garantizan': {'VERB': {'lemma': 'garantizar', 'count': 1}},
#  'garantizamos': {'VERB': {'lemma': 'garantizar', 'count': 1}},
#  'garantizarles': {'VERB': {'lemma': 'garantizar', 'count': 5}},
#  'aquella': {'ADJ': {'lemma': 'aquella', 'count': 17}},
#  'aquellas': {'ADJ': {'lemma': 'aquella', 'count': 37}},
#  'ninguna': {'ADJ': {'lemma': 'ninguna', 'count': 54}},
#  'defiendo': {'VERB': {'lemma': 'defender', 'count': 6}},
#  'defenderla': {'VERB': {'lemma': 'defender', 'count': 1}},
#  'defender': {'VERB': {'lemma': 'defender', 'count': 20}},
#  'defienden': {'VERB': {'lemma': 'defender', 'count': 10}},
#  'defiende': {'VERB': {'lemma': 'defender', 'count': 6}},
#  'defendemos': {'VERB': {'lemma': 'defender', 'count': 4}},
#  'defendiendo': {'VERB': {'lemma': 'defender', 'count': 2}},
#  'defendían': {'VERB': {'lemma': 'defender', 'count': 1}},
#  'defendido': {'VERB': {'lemma': 'defender', 'count': 1}},
#  'defiendan': {'VERB': {'lemma': 'defender', 'count': 2}},
#  'debatamos': {'VERB': {'lemma': 'debatir', 'count': 1}},
#  'debaten': {'VERB': {'lemma': 'debatir', 'count': 1}},
#  'debatirlo': {'VERB': {'lemma': 'debatir', 'count': 1}},
#  'debatimos': {'VERB': {'lemma': 'debatir', 'count': 9}},
#  'debatiendo': {'VERB': {'lemma': 'debatir', 'count': 19}},
#  'debatir': {'VERB': {'lemma': 'debatir', 'count': 10}},
#  'debatió': {'VERB': {'lemma': 'debatir', 'count': 5}},
#  'debatido': {'VERB': {'lemma': 'debatir', 'count': 4}},
#  'debatidas': {'VERB': {'lemma': 'debatir', 'count': 1}},
#  'debatidos': {'VERB': {'lemma': 'debatir', 'count': 2}},
#  'concepciones': {'NOUN': {'lemma': 'concepción', 'count': 1}},
#  'concepción': {'NOUN': {'lemma': 'concepción', 'count': 52}},
#  'vivan': {'VERB': {'lemma': 'vivir', 'count': 3}},
#  'vivir': {'VERB': {'lemma': 'vivir', 'count': 16}},
#  'vivimos': {'VERB': {'lemma': 'vivir', 'count': 14}},
#  'vive': {'VERB': {'lemma': 'vivir', 'count': 6}},
#  'viviendo': {'VERB': {'lemma': 'vivir', 'count': 5}},
#  'viven': {'VERB': {'lemma': 'vivir', 'count': 4}},
#  'viví': {'VERB': {'lemma': 'vivir', 'count': 1}},
#  'vivíamos': {'VERB': {'lemma': 'vivir', 'count': 1}},
#  'vivido': {'VERB': {'lemma': 'vivir', 'count': 1}},
#  'viva': {'VERB': {'lemma': 'vivir', 'count': 1}},
#  'vivamos': {'VERB': {'lemma': 'vivir', 'count': 1}},
#  'alguna': {'ADJ': {'lemma': 'alguna', 'count': 23}},
#  'algunas': {'ADJ': {'lemma': 'alguna', 'count': 30}},
#  'oportunidad': {'NOUN': {'lemma': 'oportunidad', 'count': 37}},
#  'oportunidades': {'NOUN': {'lemma': 'oportunidad', 'count': 16}},
#  'toda': {'ADJ': {'lemma': 'toda', 'count': 53}},
#  'cumplirla': {'VERB': {'lemma': 'cumplir', 'count': 2}},
#  'cumplirse': {'VERB': {'lemma': 'cumplir', 'count': 1}},
#  'cumplir': {'VERB': {'lemma': 'cumplir', 'count': 17}},
#  'cumpliendo': {'VERB': {'lemma': 'cumplir', 'count': 10}},
#  'cumpla': {'VERB': {'lemma': 'cumplir', 'count': 5}},
#  'cumplen': {'VERB': {'lemma': 'cumplir', 'count': 4}},
#  'cumple': {'VERB': {'lemma': 'cumplir', 'count': 4}},
#  'cumplan': {'VERB': {'lemma': 'cumplir', 'count': 3}},
#  'cumplió': {'VERB': {'lemma': 'cumplir', 'count': 1}},
#  'cumplirá': {'VERB': {'lemma': 'cumplir', 'count': 1}},
#  'cumplo': {'VERB': {'lemma': 'cumplir', 'count': 1}},
#  'cumplido': {'VERB': {'lemma': 'cumplir', 'count': 3},
#   'ADJ': {'lemma': 'cumplido', 'count': 3}},
#  'muriéndose': {'VERB': {'lemma': 'morir', 'count': 1}},
#  'mueran': {'VERB': {'lemma': 'morir', 'count': 3}},
#  'morir': {'VERB': {'lemma': 'morir', 'count': 16}},
#  'mueren': {'VERB': {'lemma': 'morir', 'count': 13}},
#  'muriendo': {'VERB': {'lemma': 'morir', 'count': 7}},
#  'murieron': {'VERB': {'lemma': 'morir', 'count': 4}},
#  'muere': {'VERB': {'lemma': 'morir', 'count': 2}},
#  'morirán': {'VERB': {'lemma': 'morir', 'count': 2}},
#  'morimos': {'VERB': {'lemma': 'morir', 'count': 1}},
#  'muerto': {'VERB': {'lemma': 'morir', 'count': 1},
#   'ADJ': {'lemma': 'muerto', 'count': 3}},
#  'muera': {'VERB': {'lemma': 'morir', 'count': 2}},
#  'resolverlo': {'VERB': {'lemma': 'resolver', 'count': 3}},
#  'resolverlos': {'VERB': {'lemma': 'resolver', 'count': 2}},
#  'resolver': {'VERB': {'lemma': 'resolver', 'count': 27}},
#  'resuelve': {'VERB': {'lemma': 'resolver', 'count': 7}},
#  'resolvió': {'VERB': {'lemma': 'resolver', 'count': 5}},
#  'resolvieron': {'VERB': {'lemma': 'resolver', 'count': 4}},
#  'resuelto': {'VERB': {'lemma': 'resolver', 'count': 1}},
#  'resuelven': {'VERB': {'lemma': 'resolver', 'count': 1}},
#  ...}

# %%
out_file = os.path.join(DATA_PATH, "words2lemmas.json")
#with open(out_file, "w") as f:
#    json.dump(tokens2lemmas, f, ensure_ascii=False, indent=4)

# %%
# TODO
# hacer gráfico de distribucion de palabras
